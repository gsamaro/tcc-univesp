# %%
import basedosdados as bd

# %%
# Para carregar o dado direto no pandas
df = bd.read_table(dataset_id='br_inep_saeb',
table_id='aluno_ef_9ano',
billing_project_id="tcc-univesp-374315")
# Out:
# Downloading:   2%|█▊                                                                                   | 867765/39377268 [23:59<18:11:57, 587.77rows/s]
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ C:\Users\99827604\AppData\Local\Temp\ipykernel_15656\1122720230.py:2 in <cell line: 2>           │
# │                                                                                                  │
# │ [Errno 2] No such file or directory:                                                             │
# │ 'C:\\Users\\99827604\\AppData\\Local\\Temp\\ipykernel_15656\\1122720230.py'                      │
# │                                                                                                  │
# │ C:\Users\99827604\Anaconda3\envs\univesp\lib\site-packages\basedosdados\download\download.py:163 │
# │ in read_table                                                                                    │
# ...
